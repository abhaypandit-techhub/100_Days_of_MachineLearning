# %% [markdown]
# ## 1.) Openiing a CSV file from an URL(from server)
# ### code snippet

# %%
import pandas as pd
import requests
from io import StringIO

url = "https://raw.githubusercontent.com/cs109/2014_data/master/countries.csv"

headers = {
    "User-Agent": "Mozilla/5.0 (Macintosh; Intel Mac OS X 10.14; rv:66.0) Gecko/20100101 Firefox/66.0"
}

req = requests.get(url, headers=headers)

data = StringIO(req.text)

df = pd.read_csv(data)

print(df.head())
# Out:
#     Country  Region
# 0   Algeria  AFRICA
# 1    Angola  AFRICA
# 2     Benin  AFRICA
# 3  Botswana  AFRICA
# 4   Burkina  AFRICA

# %%
df=pd.read_csv("https://raw.githubusercontent.com/cs109/2014_data/master/countries.csv")

# %%
df
# Out:
#        Country         Region
# 0      Algeria         AFRICA
# 1       Angola         AFRICA
# 2        Benin         AFRICA
# 3     Botswana         AFRICA
# 4      Burkina         AFRICA
# ..         ...            ...
# 189   Paraguay  SOUTH AMERICA
# 190       Peru  SOUTH AMERICA
# 191   Suriname  SOUTH AMERICA
# 192    Uruguay  SOUTH AMERICA
# 193  Venezuela  SOUTH AMERICA
#
# [194 rows x 2 columns]

# %% [markdown]
# ## 2.) sep parameter
# code snippet # also column name is not mentioned
# Assigns new column names
# pd.read_csv('movie.tsv',sep='\t',name=[col1,col2,]) # you can provide column name also using name
# ## 3.) Index_col parameter
# code snippet :
#
# pd.read_csv('xx.csv',index_col='column_name') # now column_name is new index
#
# ## 4.) Header paramter
# code snippet :
#
# pd.read_csv('xx.csv',header=1) # it says that your first row start with 1
#
# ## 5.) use_cols parameter
# code snippet :
#
# -- Need of specific column during loading the data
#
# pd.read_csv('xx.csv',usecols=['id','name',...]) # put only those column , you required
#
# ## 6.) Squeeze parameters
# pd.read_csv('xx.csv',usecols=['gender'],squeeze=True) # this is pandas series
#
# ## 7.) skiprows/nrows parameter
#  skip sepcific row
#
# pd.read_csv('xx.csv',skiprows=[0,1])
#
# pd.read_csv('xx.csv',nrows=100) # 100 rows import left skip now
#
# ## 8.) Encoding Parameter
# UnicodeDecodeError # it shows encoding is not utf-8
#
# pd.read_csv('xx.csv',encoding='latin-1') # encding format latin-1
#
# ## 9.) skip bad lines
# pd.read_csv('xx.csv',sep=';',encoding='latin-1',error_bad_lines=False) # parser error
#
# ## 10.) dtypes  paramter
# pd.read_csv('xx.csv',dtype={'column_name':int}) # changing data type of column
#
# ## 11.) Handling Dates
# -- In pandas object is considered as string
#
# pd.read_csv('xx.csv',parse_dates=['column_name']) # now it is considered  as date
#
# ## 12.) convertors
#
# df rename (name) :
#
# if name == 'Royal challengers Bangalore':
#
# return 'RCB'
#
# else:
#
# return name
#
# pd.read_csv('xx.csv',converters={'team1':rename})
#
# ## 13.) na_values parameter
#
# NaN is missing value
#
# pd.read_csv('xx.csv',na_values=['Male'])  # passing those value want to be a missing
#
# pd.read_csv('xx.csv',na_values=['Male',]) # many value can be pass use with comma

# %% [markdown]
# ## 14.) loading a huge dataset in chunks
#
# dfs=pd.read_csv('xx.csv',chunksize=5000) # made data into 5000 thousand of chunk
#
#
# for chunks in dfs :
#
# print(chunk.shape)
